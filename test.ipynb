# %%
import customtkinter as tk
from PIL import Image


#setting the appearance of the login window, built in apperance mode "dark"
tk.set_appearance_mode("dark")
tk.set_default_color_theme("blue")
titan_app = tk.CTk()

#create the geometry and the window name for the app
titan_app.title("---Titan App---")
titan_app.geometry("500x500")

#https://tkinter.com/images-in-customtkinter-tkinter-customtkinter-17/ used to help with images in custuomtkinter
# this defines the image in "image_files" folder in vscode
backround_img = tk.CTkImage(
    light_image=Image.open("image_files/dark_image.jpg"),
    dark_image=Image.open("image_files/light_image.png"),
    size=(2000,1000)
)

image_label = tk.CTkLabel(master=titan_app, 
    text="",
    width=650,
    height=650,
    image=backround_img
)
image_label.place(relx=0.5, rely=0.5, relwidth=1.0, relheight=1.0, anchor="center")


#entry box for entering username and also entry box for entering password
#will be checked against database
username_txt = tk.CTkEntry(master=titan_app,
    placeholder_text="username",
    width = 300
)
username_txt.place(relx=0.5, rely=0.2, anchor="center")

password_txt = tk.CTkEntry(master=titan_app,
    placeholder_text="password",
    width = 300
)
password_txt.place(relx=0.5, rely=0.3, anchor="center")

#button for login, command will later be assigned to checking the input of a text box
#against database
log_button = tk.CTkButton(master=titan_app, 
    text="Log In",
    font=(("comicsans",15)),
    hover_color="green",
    corner_radius=70,
    height=30,
    anchor="center"
    )
log_button.place(relx=0.48, rely=0.5, anchor="e")

#another button, this one foe sign up, will be used to prompt the user to make an account
sign_up_button = tk.CTkButton(master=titan_app, 
    text="sign up",
    font=(("comicsans",15)),
    hover_color="green",
    corner_radius=70,
    height=30,
    )
sign_up_button.place(relx=0.52, rely=0.5, anchor="w")

#button for when a password is forgotten, prompts the user to enter a passkey to change password
forgot_pass_button = tk.CTkButton(master=titan_app, 
    text="forgot password",
    font=(("comicsans",15)),
    hover_color="green",
    corner_radius=70,
    height=30,
    width=70
    )
forgot_pass_button.place(relx=0.5, rely=0.57, relwidth=0.6, relheight=0.06, anchor="center")

titan_app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#      12 titan_app.geometry("500x500")
#      14 #https://tkinter.com/images-in-customtkinter-tkinter-customtkinter-17/ used to help with images in custuomtkinter
#      15 # this defines the image in "image_files" folder in vscode
# ---> 16 backround_img = tk.CTkImage(
#      17     light_image=Image.open("image_files/dark_image.jpg"),
#      18     dark_image=Image.open("image_files/light_image.png"),
#      19     size=(2000,1000)
#      20 )
#      22 image_label = tk.CTkLabel(master=titan_app,
#      23     text="",
#      24     width=650,
#      25     height=650,
#      26     image=backround_img
#      27 )
#      28 image_label.place(relx=0.5, rely=0.5, relwidth=1.0, relheight=1.0, anchor="center")
#
# ...

# %%
import customtkinter as tk
from PIL import Image


#setting the appearance of the login window, built in apperance mode "dark"
tk.set_appearance_mode("dark")
tk.set_default_color_theme("blue")
titan_app = tk.CTk()

#create the geometry and the window name for the app
titan_app.title("---Titan App---")
titan_app.geometry("700x700")

#CTkImage defines the images for light and dark mode it uses Image imported from PIL
backround_img = tk.CTkImage(
    dark_image=Image.open("image_files/wobbly_image.png"),
    light_image=Image.open("image_files/light_image.png"),
    size=(2000,1000)
)

#actual label where the image is placed, the size of this determines the size of the image or how it appears
image_label = tk.CTkLabel(master=titan_app, 
    text="",
    width=650,
    height=650,
    image=backround_img
)
image_label.place(relx=0.5, rely=0.5, relwidth=1.0, relheight=1.0, anchor="center")

#frame wich contains all elements that the user interacts with
login_frame = tk.CTkFrame(master=titan_app,
    fg_color="black",
    width=400,
    height=400,
    corner_radius=30,
    border_width=0.9,
    border_color="white",
    background_corner_colors=("black,") ,
    image = backround_img
)
login_frame.place(relx=0.5, rely=0.5, anchor="center")

info_text = tk.CTkLabel(master=login_frame,
    fg_color="black",
    width=75,
    height=5,
    text="Enter username & password",
    text_color="white",
    font=(("comicsans",20)),        
)
info_text.place(relx=0.5, rely=0.125, relwidth=0.7, relheight=0.10, anchor="s")


#entry box for entering username and also entry box for entering password
#will be checked against database
username_entry = tk.CTkEntry(master=login_frame,
    width=75,
    height=40,
    placeholder_text="Username",
    placeholder_text_color="grey",
    corner_radius=25,
    font=(("comicsans",20)),
    fg_color="black",
    border_width=0.95,
    border_color="white",
    text_color="white"
)
username_entry.place(relx=0.5, rely=0.37, relwidth=0.97, relheight=0.23, anchor="s")

password_entry = tk.CTkEntry(master=login_frame,
    width=75,
    height=40,
    placeholder_text="Password",
    placeholder_text_color="grey",
    corner_radius=25,
    show="*",
    font=(("comicsans",20)),
    fg_color="black",
    border_width=0.95,
    border_color="white",
    text_color="white"
)
password_entry.place(relx=0.5, rely=0.61, relwidth=0.97, relheight=0.23, anchor="s")

#button for login, command will later be assigned to checking the input of a text box
#against database
log_button = tk.CTkButton(master=login_frame, 
    text="Log In",
    font=(("comicsans",20)),
    text_color="white",
    fg_color="#343638",
    hover_color="black",
    corner_radius=30,
    height=75,
    width=40,
)
log_button.place(relx=0.495, rely=0.715, relwidth=0.48, anchor="e")

#another button, this one foe sign up, will be used to prompt the user to make an account
signup_button = tk.CTkButton(master=login_frame, 
    text="Sign up",
    font=(("comicsans",20)),
    text_color="white",
    fg_color="#343638",
    hover_color="black",
    corner_radius=30,
    height=75,
    width=40,
)
signup_button.place(relx=0.505, rely=0.715, relwidth=0.48, anchor="w")

#button for when a password is forgotten, prompts the user to enter a passkey to change password
forgot_pass_button = tk.CTkButton(master=login_frame, 
    text="forgot password",
    font=(("comicsans",20)),
    text_color="white",
    fg_color="#343638",
    hover_color="black",
    corner_radius=30,
    height=65,
    width=45,
)
forgot_pass_button.place(relx=0.5, rely=0.82, relwidth=0.97, anchor="n")

titan_app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[5], line 22
#      15 backround_img = tk.CTkImage(
#      16     dark_image=Image.open("image_files/wobbly_image.png"),
#      17     light_image=Image.open("image_files/light_image.png"),
#      18     size=(2000,1000)
#      19 )
#      21 #actual label where the image is placed, the size of this determines the size of the image or how it appears
# ---> 22 image_label = tk.CTkLabel(master=titan_app,
#      23     text="",
#      24     width=650,
#      25     height=650,
#      26     image=backround_img
#      27 )
#      28 image_label.place(relx=0.5, rely=0.5, relwidth=1.0, relheight=1.0, anchor="center")
#      30 #frame wich contains all elements that the user interacts with
#
# ...

# %%
        self.current_weather_frame = tk.CTkFrame(master=self.weather_tab,
            width=500,
            height=300,
            corner_radius=35,
            fg_color="#343638",
            bg_color="black"
        )
        self.current_weather_frame.place(relx=0.2, rely=0.3, anchor="s")

        self.weather_icon = tk.CTkLabel(master=self.current_weather_frame,
            width=75,
            height=75,
            fg_color="#343638",#343638
            bg_color="#343638",
            text="",
            corner_radius=50,
            image=self.weather_img
        )
        self.weather_icon.place(relx=0.005, rely=0.65)

# %%
import ephem
import datetime

def get_moon_phase(date=None):
    if date is None:
        date = datetime.datetime.now()

    moon = ephem.Moon(date)
    phase = moon.moon_phase
    phase = round(phase,2)
    return phase

moon_phase = get_moon_phase()
print (moon_phase)
# Out:
# 0.74

# %%
from astropy.io import fits 
import matplotlib.pyplot as pt 
import os


#shows the current or changing file path and passes it into current fits
current_path = "FITS_storage\\"

def check_path(current_path):
    #user input for path
    path_inp = input ("enter path please: ")
    file_path = ((current_path)+path_inp)
    #os library argument listdir checks length of directory
    check_path = os.listdir(file_path)
    file_num = len(check_path)
    if len(check_path) == 0:
        return("<folder is empty>") #will be devloped into an error message
    else:
        name_num = [current_path,file_num]
        return(name_num) #retuns the amount of files in the folder and path used
    
def display_folder(current_path):
    check_path = os.listdir(current_path)
    file_list = [] #list to hold files
    #iteration to pass each item in folder into list
    #for use in customtkinter
    for item in check_path:
        file_list.append(item)
    return (file_list)
   
def display_fits(current_path):
    #fit file thats selected in custom tkinter will
    #be passed into "file_inp"
    file_inp = input ("selected fits passed here") 
    file_path = ((current_path)+file_inp)
    current_fit = fits.open(file_path)
    current_img = current_fit[0].data
    pt.figure
    pt.imshow(current_img, origin="lower")
    pt.colorbar
    pt.colormaps
    show = pt.show
    return (show)


disf = display_fits(current_path)
print (disf)

#list = display_folder(current_path)
#check = check_path(current_path)

#shows the current fits file that is open
#current_fits = fits.open()
# Out:
# <function show at 0x00000273C49ED120>

# %%
import pillow

Image.open(display_fits(current_path))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pillow
#       3 Image.open(display_fits(current_path))
#
# ModuleNotFoundError: No module named 'pillow'

# %%
from PIL import Image
from titan_FITS import display_fits as disf
try:
    img = Image.open(disf)
    img.show()  # Opens the image using the default image viewer
except Exception as e:
    print(f"Error opening image: {e}")

# %%
import requests
import asyncio
import winsdk.windows.devices.geolocation as wdg
from astropy.coordinates import EarthLocation, AltAz, get_sun, get_moon
from astropy.time import Time
import astropy.units as u
from astropy.coordinates import solar_system_ephemeris, get_body
import titan_gui
import astropy


#based on code by The_Redburn (https://stackoverflow.com/questions/44400560/using-windows-gps-location-service-in-a-python-script)


api_key = "4fdf1d2b85fa6d3fb20f7de7e966ce55"
      
#function to get the coridnates of the user using windows geolocator
async def get_coords():
    locator = wdg.Geolocator()
    pos = await locator.get_geoposition_async()
    gen_lat = pos.coordinate.latitude 
    gen_lon = pos.coordinate.longitude
    return [gen_lat, gen_lon]

#returns the location
def get_loc():
    try:
        return asyncio.run(get_coords())
    except PermissionError:
        return("ERROR: You need to allow applications to access you location in Windows settings")

print (get_loc())


#using the users location to tell if planets are visible
latitude, longitude = get_loc()
#location iof the observer
observe_loc = EarthLocation(lat=latitude * u.deg, lon=longitude * u.deg)

if latitude and longitude is not None:

    
    time = Time.now()
    altazframe = AltAz(obstime=time, location=observe_loc, pressure=0)
    
    with solar_system_ephemeris.set():
        mur_planet = get_body('mercury', time, observe_loc)
    
        mercury_az=mur_planet.transform_to(altazframe)

        if mercury_az < 0 * u.deg:
            print("mercury not visible ")
        else:
            print("mecrury is visible ")

# %%
from moon.jupyter_ui import JupyterUi

ui = JupyterUi()
ui.set_moon_phase() #defaults to today's date
print(ui.moon_datetime_info)
ui.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from moon.jupyter_ui import JupyterUi
#       3 ui = JupyterUi()
# ----> 4 ui.set_moon_phase() #defaults to today's date
#       5 print(ui.moon_datetime_info)
#       6 ui.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moon\dialamoon.py:50, in Moon.set_moon_phase(self, date, hour)
#      47         self.set_mooninfo_requested_date()
#      49 except Exception as e:
# ---> 50     raise e
#      51 return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moon\dialamoon.py:44, in Moon.set_moon_phase(self, date, hour)
#      42 self.set_mooninfo_requested_year()
#      43 self.set_mooninfo_requested_date()
# ...
